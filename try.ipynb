# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
k = 2

# %%
n = 3

# %%
m = 2

# %%
k*np.log(n/k) # m > than this?
# Out:
# np.float64(0.8109302162163288)

# %%
k*np.log(n/k)
# Out:
# np.float64(0.8109302162163288)

# %%
# imagine b = 0

# %%
# adjust for scale

# %%
2*k*np.log(n/k)
# Out:
# np.float64(1.6218604324326575)

# %%
3*k*np.log(n/k)
# Out:
# np.float64(2.4327906486489863)

# %%
4*k*np.log(n/k)
# Out:
# np.float64(3.243720864865315)

# %%
5*k*np.log(n/k)
# Out:
# np.float64(4.054651081081644)

# %%
# m = 2 works even for c=2
# m = 1 works for c=1

## worst case means m > k*np.log(n/k) will be one of the solutions, but there may be more solutions.
